# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
clean_df = application_df.drop(["EIN", "NAME"], axis='columns')
clean_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
clean_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_value = clean_df["APPLICATION_TYPE"].value_counts()
application_value
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(application_value[application_value < 500].index)

# Replace in dataframe
for app in application_types_to_replace:
    clean_df['APPLICATION_TYPE'] = clean_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
clean_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_list = clean_df["CLASSIFICATION"].value_counts()
classification_list
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_list[classification_list >1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(classification_list[classification_list < 1000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    clean_df['CLASSIFICATION'] = clean_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
clean_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
clean_df = pd.get_dummies(clean_df)

# %%
# Split our preprocessed data into our features and target arrays
y = clean_df["IS_SUCCESSFUL"].values
X = clean_df.drop(["IS_SUCCESSFUL"],1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
# Out:
# <ipython-input-10-b4f117835f5e>:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   X = clean_df.drop(["IS_SUCCESSFUL"],1).values

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  80
hidden_nodes_layer2 = 30

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                3520
#
#  dense_1 (Dense)             (None, 30)                2430
#
#  dense_2 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 5,981
# Trainable params: 5,981
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 6s 4ms/step - loss: 0.5716 - accuracy: 0.7209
# Epoch 2/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5567 - accuracy: 0.7295
# Epoch 3/100
# 804/804 [==============================] - 5s 6ms/step - loss: 0.5534 - accuracy: 0.7304
# Epoch 4/100
# 804/804 [==============================] - 4s 4ms/step - loss: 0.5509 - accuracy: 0.7316
# Epoch 5/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5508 - accuracy: 0.7320
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5494 - accuracy: 0.7320
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5485 - accuracy: 0.7342
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5472 - accuracy: 0.7331
# Epoch 9/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5474 - accuracy: 0.7348
# Epoch 10/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5466 - accuracy: 0.7343
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5462 - accuracy: 0.7350
# Epoch 12/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5462 - accuracy: 0.7352
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5451 - accuracy: 0.7347
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5451 - accuracy: 0.7344
# Epoch 15/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5450 - accuracy: 0.7365
# Epoch 16/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5444 - accuracy: 0.7362
# Epoch 17/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5438 - accuracy: 0.7365
# Epoch 18/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5441 - accuracy: 0.7369
# Epoch 19/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5436 - accuracy: 0.7366
# Epoch 20/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5437 - accuracy: 0.7365
# Epoch 21/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5433 - accuracy: 0.7367
# Epoch 22/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5421 - accuracy: 0.7377
# Epoch 23/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5426 - accuracy: 0.7376
# Epoch 24/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5422 - accuracy: 0.7379
# Epoch 25/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5427 - accuracy: 0.7382
# Epoch 26/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5422 - accuracy: 0.7378
# Epoch 27/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5423 - accuracy: 0.7382
# Epoch 28/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5419 - accuracy: 0.7385
# Epoch 29/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5421 - accuracy: 0.7390
# Epoch 30/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5414 - accuracy: 0.7390
# Epoch 31/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5415 - accuracy: 0.7391
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5409 - accuracy: 0.7389
# Epoch 33/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5409 - accuracy: 0.7389
# Epoch 34/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5406 - accuracy: 0.7390
# Epoch 35/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5407 - accuracy: 0.7393
# Epoch 36/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5405 - accuracy: 0.7395
# Epoch 37/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5400 - accuracy: 0.7394
# Epoch 38/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5401 - accuracy: 0.7388
# Epoch 39/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5402 - accuracy: 0.7389
# Epoch 40/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5400 - accuracy: 0.7385
# Epoch 41/100
# 804/804 [==============================] - 4s 5ms/step - loss: 0.5398 - accuracy: 0.7392
# Epoch 42/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5399 - accuracy: 0.7394
# Epoch 43/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5391 - accuracy: 0.7399
# Epoch 44/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5397 - accuracy: 0.7393
# Epoch 45/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5395 - accuracy: 0.7396
# Epoch 46/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5391 - accuracy: 0.7398
# Epoch 47/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5394 - accuracy: 0.7398
# Epoch 48/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5393 - accuracy: 0.7400
# Epoch 49/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5389 - accuracy: 0.7398
# Epoch 50/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5388 - accuracy: 0.7393
# Epoch 51/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5391 - accuracy: 0.7399
# Epoch 52/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5388 - accuracy: 0.7399
# Epoch 53/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5389 - accuracy: 0.7400
# Epoch 54/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5386 - accuracy: 0.7400
# Epoch 55/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5384 - accuracy: 0.7406
# Epoch 56/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5385 - accuracy: 0.7403
# Epoch 57/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5384 - accuracy: 0.7398
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5386 - accuracy: 0.7397
# Epoch 59/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5382 - accuracy: 0.7406
# Epoch 60/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5385 - accuracy: 0.7396
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5379 - accuracy: 0.7399
# Epoch 62/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5379 - accuracy: 0.7402
# Epoch 63/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5380 - accuracy: 0.7403
# Epoch 64/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5377 - accuracy: 0.7401
# Epoch 65/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5374 - accuracy: 0.7410
# Epoch 66/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5377 - accuracy: 0.7403
# Epoch 67/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5373 - accuracy: 0.7398
# Epoch 68/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5376 - accuracy: 0.7406
# Epoch 69/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5372 - accuracy: 0.7402
# Epoch 70/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5375 - accuracy: 0.7406
# Epoch 71/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5372 - accuracy: 0.7404
# Epoch 72/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5372 - accuracy: 0.7410
# Epoch 73/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5371 - accuracy: 0.7407
# Epoch 74/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5372 - accuracy: 0.7401
# Epoch 75/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5370 - accuracy: 0.7407
# Epoch 76/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5372 - accuracy: 0.7407
# Epoch 77/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5369 - accuracy: 0.7410
# Epoch 78/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5367 - accuracy: 0.7404
# Epoch 79/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5369 - accuracy: 0.7401
# Epoch 80/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5366 - accuracy: 0.7413
# Epoch 81/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5365 - accuracy: 0.7407
# Epoch 82/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5369 - accuracy: 0.7413
# Epoch 83/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5366 - accuracy: 0.7406
# Epoch 84/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5366 - accuracy: 0.7411
# Epoch 85/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5365 - accuracy: 0.7411
# Epoch 86/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5365 - accuracy: 0.7411
# Epoch 87/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5363 - accuracy: 0.7410
# Epoch 88/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5361 - accuracy: 0.7408
# Epoch 89/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5364 - accuracy: 0.7406
# Epoch 90/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5362 - accuracy: 0.7404
# Epoch 91/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5363 - accuracy: 0.7410
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5359 - accuracy: 0.7407
# Epoch 93/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5363 - accuracy: 0.7408
# Epoch 94/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5361 - accuracy: 0.7410
# Epoch 95/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5359 - accuracy: 0.7411
# Epoch 96/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5360 - accuracy: 0.7402
# Epoch 97/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5359 - accuracy: 0.7414
# Epoch 98/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5358 - accuracy: 0.7416
# Epoch 99/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5360 - accuracy: 0.7411
# Epoch 100/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5359 - accuracy: 0.7414

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5569 - accuracy: 0.7277 - 586ms/epoch - 2ms/step
# Loss: 0.5568602681159973, Accuracy: 0.7276967763900757

# %%
# Define the 2nd model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 =  75
hidden_nodes_layer2 = 35
hidden_nodes_layer3 = 25

nn2 = tf.keras.models.Sequential()

# First hidden layer
nn2.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="tanh")
)

# Second hidden layer
nn2.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="tanh"))

# Third hidden layer
nn2.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="tanh"))

# Output layer
nn2.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 75)                3300
#
#  dense_8 (Dense)             (None, 35)                2660
#
#  dense_9 (Dense)             (None, 25)                900
#
#  dense_10 (Dense)            (None, 1)                 26
#
# =================================================================
# Total params: 6,886
# Trainable params: 6,886
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the 2nd model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the 2nd model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5340 - accuracy: 0.7420
# Epoch 2/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5341 - accuracy: 0.7413
# Epoch 3/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5337 - accuracy: 0.7412
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5335 - accuracy: 0.7407
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5340 - accuracy: 0.7415
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5334 - accuracy: 0.7413
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5333 - accuracy: 0.7421
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5335 - accuracy: 0.7414
# Epoch 9/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5336 - accuracy: 0.7409
# Epoch 10/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5333 - accuracy: 0.7416
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5333 - accuracy: 0.7413
# Epoch 12/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5334 - accuracy: 0.7412
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5334 - accuracy: 0.7412
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5335 - accuracy: 0.7415
# Epoch 15/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5333 - accuracy: 0.7408
# Epoch 16/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5331 - accuracy: 0.7420
# Epoch 17/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5334 - accuracy: 0.7413
# Epoch 18/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5328 - accuracy: 0.7414
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5331 - accuracy: 0.7420
# Epoch 20/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5332 - accuracy: 0.7418
# Epoch 21/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5329 - accuracy: 0.7417
# Epoch 22/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5330 - accuracy: 0.7418
# Epoch 23/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5331 - accuracy: 0.7410
# Epoch 24/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5332 - accuracy: 0.7418
# Epoch 25/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5329 - accuracy: 0.7427
# Epoch 26/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5330 - accuracy: 0.7418
# Epoch 27/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5329 - accuracy: 0.7415
# Epoch 28/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5330 - accuracy: 0.7413
# Epoch 29/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5330 - accuracy: 0.7418
# Epoch 30/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5325 - accuracy: 0.7412
# Epoch 31/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5330 - accuracy: 0.7415
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5328 - accuracy: 0.7418
# Epoch 33/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5327 - accuracy: 0.7417
# Epoch 34/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5326 - accuracy: 0.7418
# Epoch 35/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5328 - accuracy: 0.7420
# Epoch 36/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5324 - accuracy: 0.7419
# Epoch 37/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5327 - accuracy: 0.7417
# Epoch 38/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5331 - accuracy: 0.7415
# Epoch 39/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5324 - accuracy: 0.7413
# Epoch 40/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5324 - accuracy: 0.7416
# Epoch 41/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5326 - accuracy: 0.7422
# Epoch 42/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5327 - accuracy: 0.7420
# Epoch 43/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5324 - accuracy: 0.7415
# Epoch 44/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5327 - accuracy: 0.7419
# Epoch 45/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5327 - accuracy: 0.7409
# Epoch 46/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5324 - accuracy: 0.7420
# Epoch 47/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5323 - accuracy: 0.7423
# Epoch 48/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5322 - accuracy: 0.7417
# Epoch 49/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5323 - accuracy: 0.7421
# Epoch 50/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5325 - accuracy: 0.7421
# Epoch 51/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5323 - accuracy: 0.7414
# Epoch 52/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5323 - accuracy: 0.7417
# Epoch 53/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7420
# Epoch 54/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5327 - accuracy: 0.7421
# Epoch 55/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5324 - accuracy: 0.7419
# Epoch 56/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5317 - accuracy: 0.7417
# Epoch 57/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5322 - accuracy: 0.7420
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5321 - accuracy: 0.7420
# Epoch 59/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5321 - accuracy: 0.7420
# Epoch 60/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5322 - accuracy: 0.7417
# Epoch 61/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5321 - accuracy: 0.7417
# Epoch 62/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5321 - accuracy: 0.7416
# Epoch 63/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5324 - accuracy: 0.7419
# Epoch 64/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5322 - accuracy: 0.7423
# Epoch 65/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5319 - accuracy: 0.7424
# Epoch 66/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7424
# Epoch 67/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5317 - accuracy: 0.7418
# Epoch 68/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5321 - accuracy: 0.7425
# Epoch 69/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7421
# Epoch 70/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5320 - accuracy: 0.7421
# Epoch 71/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5320 - accuracy: 0.7421
# Epoch 72/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5322 - accuracy: 0.7419
# Epoch 73/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5319 - accuracy: 0.7423
# Epoch 74/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7427
# Epoch 75/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5319 - accuracy: 0.7426
# Epoch 76/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5318 - accuracy: 0.7421
# Epoch 77/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5316 - accuracy: 0.7425
# Epoch 78/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5316 - accuracy: 0.7427
# Epoch 79/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5315 - accuracy: 0.7421
# Epoch 80/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5317 - accuracy: 0.7423
# Epoch 81/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7420
# Epoch 82/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7425
# Epoch 83/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5314 - accuracy: 0.7430
# Epoch 84/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5317 - accuracy: 0.7419
# Epoch 85/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5319 - accuracy: 0.7430
# Epoch 86/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5318 - accuracy: 0.7424
# Epoch 87/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5315 - accuracy: 0.7421
# Epoch 88/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5315 - accuracy: 0.7424
# Epoch 89/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5317 - accuracy: 0.7426
# Epoch 90/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5313 - accuracy: 0.7422
# Epoch 91/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5318 - accuracy: 0.7430
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5318 - accuracy: 0.7424
# Epoch 93/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5312 - accuracy: 0.7423
# Epoch 94/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5315 - accuracy: 0.7425
# Epoch 95/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5315 - accuracy: 0.7428
# Epoch 96/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5317 - accuracy: 0.7422
# Epoch 97/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5314 - accuracy: 0.7420
# Epoch 98/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5313 - accuracy: 0.7423
# Epoch 99/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5318 - accuracy: 0.7428
# Epoch 100/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5319 - accuracy: 0.7429

# %%
# Evaluate the 2nd model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5611 - accuracy: 0.7255 - 502ms/epoch - 2ms/step
# Loss: 0.5610689520835876, Accuracy: 0.7254810333251953

# %%
# Define the 3rd model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train[0])
hidden_nodes_layer1 = 55
hidden_nodes_layer2 = 35
hidden_nodes_layer3 = 45
hidden_nodes_layer4 = 15

nn3 = tf.keras.models.Sequential()

# First hidden layer
nn3.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn3.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Third hidden layer
nn3.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))

# Fourth hidden layer
nn3.add(tf.keras.layers.Dense(units=hidden_nodes_layer4, activation="relu"))

# Output layer
nn3.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn3.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_11 (Dense)            (None, 55)                2420
#
#  dense_12 (Dense)            (None, 35)                1960
#
#  dense_13 (Dense)            (None, 45)                1620
#
#  dense_14 (Dense)            (None, 15)                690
#
#  dense_15 (Dense)            (None, 1)                 16
#
# =================================================================
# Total params: 6,706
# Trainable params: 6,706
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the 3rd model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the 3rd model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 4s 3ms/step - loss: 0.5319 - accuracy: 0.7424
# Epoch 2/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5315 - accuracy: 0.7425
# Epoch 3/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5317 - accuracy: 0.7422
# Epoch 4/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5315 - accuracy: 0.7425
# Epoch 5/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5311 - accuracy: 0.7422
# Epoch 6/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7423
# Epoch 7/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5313 - accuracy: 0.7427
# Epoch 8/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5312 - accuracy: 0.7425
# Epoch 9/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5311 - accuracy: 0.7428
# Epoch 10/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5313 - accuracy: 0.7429
# Epoch 11/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5313 - accuracy: 0.7423
# Epoch 12/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5310 - accuracy: 0.7422
# Epoch 13/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5312 - accuracy: 0.7419
# Epoch 14/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5312 - accuracy: 0.7431
# Epoch 15/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5311 - accuracy: 0.7426
# Epoch 16/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5311 - accuracy: 0.7427
# Epoch 17/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5315 - accuracy: 0.7427
# Epoch 18/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5309 - accuracy: 0.7425
# Epoch 19/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5310 - accuracy: 0.7430
# Epoch 20/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5309 - accuracy: 0.7428
# Epoch 21/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5310 - accuracy: 0.7431
# Epoch 22/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5312 - accuracy: 0.7427
# Epoch 23/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5310 - accuracy: 0.7432
# Epoch 24/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5309 - accuracy: 0.7426
# Epoch 25/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5307 - accuracy: 0.7423
# Epoch 26/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5311 - accuracy: 0.7426
# Epoch 27/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5310 - accuracy: 0.7422
# Epoch 28/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5308 - accuracy: 0.7423
# Epoch 29/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5309 - accuracy: 0.7425
# Epoch 30/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5311 - accuracy: 0.7432
# Epoch 31/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5309 - accuracy: 0.7428
# Epoch 32/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5310 - accuracy: 0.7423
# Epoch 33/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5308 - accuracy: 0.7420
# Epoch 34/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5309 - accuracy: 0.7423
# Epoch 35/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5309 - accuracy: 0.7427
# Epoch 36/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5304 - accuracy: 0.7430
# Epoch 37/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5305 - accuracy: 0.7427
# Epoch 38/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5308 - accuracy: 0.7431
# Epoch 39/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5312 - accuracy: 0.7426
# Epoch 40/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5310 - accuracy: 0.7423
# Epoch 41/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5307 - accuracy: 0.7424
# Epoch 42/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5306 - accuracy: 0.7428
# Epoch 43/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5306 - accuracy: 0.7426
# Epoch 44/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5308 - accuracy: 0.7426
# Epoch 45/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5308 - accuracy: 0.7421
# Epoch 46/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5306 - accuracy: 0.7426
# Epoch 47/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5304 - accuracy: 0.7424
# Epoch 48/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5306 - accuracy: 0.7429
# Epoch 49/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5312 - accuracy: 0.7427
# Epoch 50/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5305 - accuracy: 0.7432
# Epoch 51/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5305 - accuracy: 0.7431
# Epoch 52/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5308 - accuracy: 0.7427
# Epoch 53/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5304 - accuracy: 0.7423
# Epoch 54/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5307 - accuracy: 0.7432
# Epoch 55/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5304 - accuracy: 0.7430
# Epoch 56/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5308 - accuracy: 0.7423
# Epoch 57/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5303 - accuracy: 0.7428
# Epoch 58/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5304 - accuracy: 0.7432
# Epoch 59/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5303 - accuracy: 0.7430
# Epoch 60/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5304 - accuracy: 0.7426
# Epoch 61/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5307 - accuracy: 0.7425
# Epoch 62/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5305 - accuracy: 0.7420
# Epoch 63/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5310 - accuracy: 0.7434
# Epoch 64/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5303 - accuracy: 0.7427
# Epoch 65/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5312 - accuracy: 0.7428
# Epoch 66/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5304 - accuracy: 0.7428
# Epoch 67/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5305 - accuracy: 0.7431
# Epoch 68/100
# 804/804 [==============================] - 3s 3ms/step - loss: 0.5306 - accuracy: 0.7432
# Epoch 69/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5304 - accuracy: 0.7432
# Epoch 70/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5309 - accuracy: 0.7431
# Epoch 71/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5303 - accuracy: 0.7428
# Epoch 72/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5308 - accuracy: 0.7427
# Epoch 73/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5305 - accuracy: 0.7428
# Epoch 74/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5306 - accuracy: 0.7427
# Epoch 75/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5305 - accuracy: 0.7432
# Epoch 76/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5305 - accuracy: 0.7428
# Epoch 77/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5304 - accuracy: 0.7432
# Epoch 78/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5301 - accuracy: 0.7427
# Epoch 79/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5303 - accuracy: 0.7432
# Epoch 80/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5305 - accuracy: 0.7417
# Epoch 81/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5306 - accuracy: 0.7419
# Epoch 82/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5307 - accuracy: 0.7427
# Epoch 83/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5304 - accuracy: 0.7426
# Epoch 84/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5305 - accuracy: 0.7428
# Epoch 85/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5304 - accuracy: 0.7430
# Epoch 86/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5302 - accuracy: 0.7430
# Epoch 87/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5302 - accuracy: 0.7427
# Epoch 88/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5302 - accuracy: 0.7429
# Epoch 89/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5299 - accuracy: 0.7427
# Epoch 90/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5298 - accuracy: 0.7431
# Epoch 91/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5302 - accuracy: 0.7431
# Epoch 92/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5304 - accuracy: 0.7432
# Epoch 93/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5303 - accuracy: 0.7429
# Epoch 94/100
# 804/804 [==============================] - 3s 4ms/step - loss: 0.5304 - accuracy: 0.7432
# Epoch 95/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5301 - accuracy: 0.7429
# Epoch 96/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5304 - accuracy: 0.7430
# Epoch 97/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5300 - accuracy: 0.7430
# Epoch 98/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5311 - accuracy: 0.7430
# Epoch 99/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5302 - accuracy: 0.7431
# Epoch 100/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5302 - accuracy: 0.7431

# %%
# Evaluate the 3rd model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.5710 - accuracy: 0.7256 - 567ms/epoch - 2ms/step
# Loss: 0.5710201859474182, Accuracy: 0.7255976796150208

# %%
# Export our model to HDF5 file
nn.save("model.h5")
print("Saved model to HDF5 file")
# Out:
# Saved model to HDF5 file
